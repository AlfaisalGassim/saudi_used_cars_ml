# %%
import pandas as pd

# %%
carsRaw = pd.read_csv("../data/cars.csv")

# %%
carsRaw.head()
# Out:
#    Unnamed: 0       Make      Type  Year Origin  Color    Options  \
# 0        6153     Toyota     Camry  2020  Saudi  Brown  Semi Full
# 1        4434     Toyota        FJ  2012  Saudi  Black       Full
# 2        3537  Chevrolet  Suburban  2009  Saudi  White   Standard
# 3        1666       Ford  Explorer  2016  Other  White       Full
# 4        3513     Toyota   Corolla  2018  Saudi  White   Standard
#
#    Engine_Size Fuel_Type  Gear_Type  Mileage  Region   Price  Negotiable
# 0          2.5       Gas  Automatic    38000  Riyadh    1364       False
# 1          4.0       Gas  Automatic    35000  Riyadh   70000       False
# 2          5.3       Gas  Automatic      255  Riyadh   36000       False
# 3          3.5       Gas  Automatic   128644  Riyadh  118000       False
# 4          1.6       Gas  Automatic    19190  Jeddah   55000       False

# %%
carsRaw.shape
# Out:
# (6428, 14)

# %%
carsRaw[carsRaw["Price"] <= 0]
# Out:
#       Unnamed: 0       Make        Type  Year       Origin          Color  \
# 6           6220      Lexus          LS  1998        Other            Red
# 8           4507  Chevrolet       Tahoe  2013        Other          Black
# 9           3456     Toyota     4Runner  2013        Saudi  Another Color
# 11          7395     Toyota      Previa  2010  Gulf Arabic           Grey
# 12          3014  Chevrolet       Tahoe  2016        Saudi         Golden
# ...          ...        ...         ...   ...          ...            ...
# 6415        6253  Chevrolet     Caprice  2014        Saudi  Another Color
# 6416        7932    Hyundai      Accent  2019        Saudi           Blue
# 6418        4489      Lexus          LX  2014  Gulf Arabic         Golden
# 6421        3671     Nissan      Patrol  1994  Gulf Arabic          Black
# 6427        1146       Ford  Expedition  2006        Other          Black
#
#         Options  Engine_Size Fuel_Type  Gear_Type  Mileage   Region  Price  \
# ...

# %%
carsNoZeros = carsRaw.drop(carsRaw[carsRaw["Price"] <= 0].index).reset_index()

# %% [markdown]
# ### Save the new data frame to csv in data dir

# %%
carsNoZeros.to_csv("../data/carsNoZeros.csv")
